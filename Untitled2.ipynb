# %%
import pandas as pd, numpy as np

# %%
def loadgff(path=None,sr=16, dropsource=True,zerobase=True,
            cols=['chrom','source','type','start','end',
                  'score','strand','phase','attribute']):
    """
    Loads a gff as pandas dataframe and assignes column names.
    Skips SR rows of the gff file and assigns column names COLS.
    """
    if path is None:
        path = '/Users/croth/Downloads/FungiDB-41_CneoformansJEC21.gff'
    gff = pd.read_table(path,header=None,skiprows=sr) ## Load the gff file via pandas
    gff.index = gff.index + sr ## reset index to match row id in original gff file
    gff.columns = cols ## Rename colunms
    if dropsource:
        gff.drop(['source','score'],axis=1,inplace=True)
    if zerobase:
        gff['start'] = gff['start'] - 1
    return gff

# %%
def addgene(gff,col='attribute'):
    return [a.split(';')[0].split('.')[0].split('-')[0].split('_')[-1].split('ID=')[-1] 
             for a in gff[col].tolist()]

def addtogff(gff,ret='description=',col='attribute'):
    descripts = [[a for a in b.split(';') if ret in a]
         for b in gff[col].tolist()]
    descripts_return = []
    for d in descripts:
        if len(d) > 0:
            descripts_return.append(d[0].split(ret)[-1])
        else:
            descripts_return.append(np.nan)
    return descripts_return

# %%
## load in the JEC21 sequence file
jgff = loadgff()
jgff.shape
# Out:
# /Users/croth/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   # Remove the CWD from sys.path while we load stuff.
# (119444, 7)

# %%
## Add gene name
jgff['gene'] = addgene(jgff)
jgff['description'] = addtogff(jgff)
jgff['id'] = addtogff(jgff,ret='ID=')

# %%
bounds = jgff[(jgff.type=='gene') & (jgff.id.isin(['CNB02850','CNB03330']))]

# %%
left = np.min(np.concatenate(bounds[['start','end']].values))
right = np.max(np.concatenate(bounds[['start','end']].values))

# %%
jgff.head()
# Out:
#          chrom  type   start     end strand phase  \
# 16  AE017352.1  gene  713523  714773      -     .
# 17  AE017352.1  mRNA  713523  714773      -     .
# 18  AE017352.1  exon  713523  713666      -     .
# 19  AE017352.1  exon  713719  713815      -     .
# 20  AE017352.1  exon  713865  714350      -     .
#
#                                             attribute      gene  \
# 16  ID=CNL06190;description=aldo-keto reductase%2C...  CNL06190
# 17  ID=CNL06190-t26_1;Parent=CNL06190;description=...  CNL06190
# 18          ID=exon_CNL06190-E5;Parent=CNL06190-t26_1  CNL06190
# 19          ID=exon_CNL06190-E4;Parent=CNL06190-t26_1  CNL06190
# 20          ID=exon_CNL06190-E3;Parent=CNL06190-t26_1  CNL06190
#
#                         description                id
# 16  aldo-keto reductase%2C putative          CNL06190
# 17  aldo-keto reductase%2C putative    CNL06190-t26_1
# 18                              NaN  exon_CNL06190-E5
# 19                              NaN  exon_CNL06190-E4
# 20                              NaN  exon_CNL06190-E3

# %%
## Load gene anlaysis
gene_analysis = pd.read_csv('../FILES/XL280_431_gene_analysis.csv.gz')
gene_analysis.head()
# Out:
#    chrom      gene  mod_three  length_check  nonsense  missense
# 0  Chr01  CNA04490          0             0         0         2
# 1  Chr01  CNA05630          0             0         0         2
# 2  Chr01  CNA04300          0             0         0         0
# 3  Chr01  CNA08210          0             0         0         0
# 4  Chr01  CNA00370          0             0         0         3

# %%
genes_in_qtl_maybe = jgff[(jgff.chrom=='AE017342.1') & 
     (jgff.start.isin(np.arange(left,right+1))) & 
     (jgff.type=='gene')].sort_values('start').id.tolist()

# %%
len([g for g in genes_in_qtl_maybe if g not in gene_analysis.gene.tolist()])
# Out:
# 15

# %%
jgff[(jgff.id.isin([g for g in genes_in_qtl_maybe if g not in gene_analysis.gene.tolist()]))].sort_values('id')
# Out:
#              chrom  type   start     end strand phase  \
# 65849   AE017342.1  gene  850460  852258      -     .
# 112652  AE017342.1  gene  852305  853767      -     .
# 82602   AE017342.1  gene  853851  855449      +     .
# 118138  AE017342.1  gene  856408  862548      +     .
# 6061    AE017342.1  gene  865735  877066      -     .
# 36341   AE017342.1  gene  878805  885495      -     .
# 93260   AE017342.1  gene  885495  890169      +     .
# 63194   AE017342.1  gene  890392  896167      -     .
# 85380   AE017342.1  gene  896256  897579      +     .
# 6803    AE017342.1  gene  903367  903655      +     .
# 13374   AE017342.1  gene  905037  907266      -     .
# 84449   AE017342.1  gene  907474  909293      -     .
# 33802   AE017342.1  gene  925353  926169      -     .
# 8998    AE017342.1  gene  929776  930991      +     .
# 18301   AE017342.1  gene  951048  952399      -     .
#
#                                                 attribute      gene  \
# 65849   ID=CNB02880;description=endoplasmic reticulum ...  CNB02880
# 112652  ID=CNB02890;description=purine-specific oxidiz...  CNB02890
# 82602   ID=CNB02900;description=serine/threonine-prote...  CNB02900
# 118138        ID=CNB02910;description=unspecified product  CNB02910
# 6061          ID=CNB02920;description=unspecified product  CNB02920
# 36341         ID=CNB02930;description=unspecified product  CNB02930
# 93260         ID=CNB02940;description=unspecified product  CNB02940
# 63194         ID=CNB02950;description=unspecified product  CNB02950
# 85380         ID=CNB02960;description=unspecified product  CNB02960
# 6803          ID=CNB02970;description=unspecified product  CNB02970
# 13374   ID=CNB02980;description=calcium:hydrogen antip...  CNB02980
# 84449   ID=CNB02990;description=acyltransferase%2C put...  CNB02990
# 33802   ID=CNB03050;description=pre-mRNA splicing fact...  CNB03050
# 8998    ID=CNB03080;description=nucleolus protein%2C p...  CNB03080
# 18301        ID=CNB03155;description=hypothetical protein  CNB03155
#
#                                               description        id
# 65849           endoplasmic reticulum protein%2C putative  CNB02880
# 112652  purine-specific oxidized base lesion DNA N-gly...  CNB02890
# 82602         serine/threonine-protein kinase%2C putative  CNB02900
# 118138                                unspecified product  CNB02910
# 6061                                  unspecified product  CNB02920
# 36341                                 unspecified product  CNB02930
# 93260                                 unspecified product  CNB02940
# 63194                                 unspecified product  CNB02950
# 85380                                 unspecified product  CNB02960
# 6803                                  unspecified product  CNB02970
# 13374             calcium:hydrogen antiporter%2C putative  CNB02980
# 84449                         acyltransferase%2C putative  CNB02990
# 33802                pre-mRNA splicing factor%2C putative  CNB03050
# 8998                        nucleolus protein%2C putative  CNB03080
# 18301                                hypothetical protein  CNB03155

# %%
len([g for g in genes_in_qtl_maybe if g in gene_analysis.gene.tolist()])
# Out:
# 38

# %%
jgff[(jgff.id=='CNB03220')]
# Out:
#             chrom  type   start     end strand phase  \
# 21476  AE017342.1  gene  972411  974648      +     .
#
#                                          attribute      gene  \
# 21476  ID=CNB03220;description=unspecified product  CNB03220
#
#                description        id
# 21476  unspecified product  CNB03220

# %%
gene_analysis[(gene_analysis.gene.isin(genes_in_qtl_maybe))].sort_values('gene')
# Out:
#       chrom      gene  mod_three  length_check  nonsense  missense
# 828   Chr02  CNB02850          0             0         0         5
# 849   Chr02  CNB02860          0             0         0         3
# 988   Chr02  CNB02870          0             0         0         0
# 982   Chr02  CNB02995          0             0         0         1
# 878   Chr02  CNB03000          0             0         0         3
# 1110  Chr02  CNB03005          0             0         0         3
# 807   Chr02  CNB03010          0             0         0         0
# 997   Chr02  CNB03020          0             0         0         2
# 1122  Chr02  CNB03030          0             0         0         2
# 875   Chr02  CNB03040          0             0         0         0
# 834   Chr02  CNB03060          0             0         0         0
# 863   Chr02  CNB03070          0             0         0         0
# 1023  Chr02  CNB03090          0             0         1        12
# 895   Chr02  CNB03100          0             0         0         0
# 1127  Chr02  CNB03110          0             0         0         1
# 936   Chr02  CNB03120          0             0         0         0
# 956   Chr02  CNB03130          0             0         0         0
# 841   Chr02  CNB03140          0             0         0         0
# 932   Chr02  CNB03150          0             0         0         0
# 781   Chr02  CNB03160          0             0         0         0
# 1146  Chr02  CNB03170          0             0         0         5
# 912   Chr02  CNB03180          0             0         0         3
# 1123  Chr02  CNB03190          0             0         0         0
# 815   Chr02  CNB03195          0             0         0         2
# 1034  Chr02  CNB03200          0             0         0         3
# 1151  Chr02  CNB03210          0             0         0         0
# 881   Chr02  CNB03215          0             0         0         3
# 951   Chr02  CNB03220          1             1         0         0
# 995   Chr02  CNB03230          0             0         0         1
# 1028  Chr02  CNB03235          0             0         0         0
# 842   Chr02  CNB03240          0             0         0         1
# 748   Chr02  CNB03250          0             0         0         0
# 965   Chr02  CNB03270          0             0         0         1
# 908   Chr02  CNB03280          0             0         0         0
# 750   Chr02  CNB03290          0             0         0         1
# 733   Chr02  CNB03300          0             0         0         3
# 790   Chr02  CNB03310          0             0         0        22
# 793   Chr02  CNB03330          0             0         1        52
