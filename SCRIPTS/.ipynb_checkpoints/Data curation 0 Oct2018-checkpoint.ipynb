# %%
## Set file date for use. As of October, this is Oct262018
filedate = 'Jan162019'
## Set file name and load with pandas
file_name = '../DATA/Tecan_qtlruns_%s.csv.gz'%(
    filedate)

# %%
## Bring in the mod pandas
import pandas as pd

# %%
## Bring in file
tecan = pd.read_csv(file_name)

# %%
## Set variables for data filtering 
## such as the plates we are using & temperatures
plates = ['qtl1','qtl2']
temps = ['30C','37C','39C']

# %%
## Filter data
data = tecan[(tecan.strain != 'blank') &      ## We don't need these. DM already did blank correction
              (tecan.premedia=='YPD') &       ## We experimented with YPD vs YNB, take only YPD 
              (tecan.length=='72hrs') &       ## All data needed to be from 72 hrs
              (tecan.date != 'Oct82017') &    ## Pre-culture plate wasn't shaken, poor growth
              (tecan.date != 'Nov162018') &   ## pre-culture was incubated incorrectly, at 37 for 24hrs
              (tecan['plate'].isin(plates)) & ## Just the qtl plates, not the others
              (tecan['temp'].isin(temps)) &   ## We are only look at these temperatures
              (tecan['amphB']!='0.312ug')
            ].copy()

# %% [markdown]
# ## Column description
#
# date - the date the data was collected
#
# row  - the row of the 96 well plate the sample was located in
#
# column - the column of the 96 well plate hte sample was located in
#
# plate - the name of the plate the sample was in
#
# temp - the temperature the experiment was conducted at
#
# strain - the strain name of the sample
#
# amphB - the concentration (ug/ml) of the antifungal drug, amphotericin B
#
# length - the duration (in hours) of the experiment
#
# Instrument - the name of the TECAN used to collect data
#
# saturatedOD - the final OD of the preculture plate used to pin from
#
# premedia - type of media used to grow samples to saturation
#
# 0s, 900s, ... - the time point OD was sampled at (seconds)

# %%
data.columns[:13]
# Out:
# Index(['date', 'row', 'column', 'plate', 'temp', 'strain', 'amphB', 'length',
#        'Instrument', 'saturatedOD', 'premedia', '0s', '900s'],
#       dtype='object')

# %%
dg = data.groupby(['strain','temp','amphB','length','plate']).agg({'saturatedOD':['count']})

# %%
dg.head()
# Out:
#                                   saturatedOD
#                                         count
# strain  temp amphB   length plate
# SS-A837 30C  0.075ug 72hrs  qtl2            4
#              0.125ug 72hrs  qtl2            4
#              0.175ug 72hrs  qtl2            4
#              0ug     72hrs  qtl2            4
#         37C  0.075ug 72hrs  qtl2            4

# %%
## Remove old data
del tecan

# %%
## Reset the data index
data.reset_index(drop=True,inplace=True)

# %%
## Print shape of dataframe
data.shape
# Out:
# (5340, 300)

# %%
## Check we have two plates
assert len(data.plate.unique()) == 2

# %%
## Write ftns we will need for later
def temp_convert(x):
    return int(x[:-1])

def length_convert(x):
    return int(x[:2])

def plate_convert(x):
    return int(x[-1])

def amphB_convert(x):
    return round(float(x[:-2]),3)

# %%
## Print the durg concentrations and check our conversion ftn
sorted([amphB_convert(a) for a in data.amphB.unique()])
# Out:
# [0.0, 0.075, 0.125, 0.175]

# %%
## Convert data (ignore the warning)
data.loc[:,'temp'] = data.loc[:,'temp'].apply(temp_convert)
data.loc[:,'length'] = data.loc[:,'length'].apply(length_convert)
data.loc[:,'plate'] = data.loc[:,'plate'].apply(plate_convert)
data.loc[:,'amphB'] = data.loc[:,'amphB'].apply(amphB_convert)

# %%
## Take unique dates
unique_dates = data.date.unique()

# %%
## Convert these dates
months = [un[:3] for un in unique_dates]
days = [int(un[3:-4]) for un in unique_dates]
year = [int(un[-4:]) for un in unique_dates]

# %%
## Bring in calendar mod
import calendar

# %%
## Make a month dictionary
month_dict = [dict((v,k) for k,v in enumerate(calendar.month_abbr))][0]

# %%
## Make a month dataframe
month_df = pd.DataFrame([unique_dates,days,months,year],
                        index=['date','day','month','year']).T

# %%
## Sort the values in month dataframe
month_df['month'] = month_df['month'].map(month_dict)
month_df.sort_values(['year','month','day'],inplace=True)
month_df.reset_index(drop=True,inplace=True)

# %%
## Set path to save month dataframe
month_df_save = '../DATA/Tecan_qtlruns_%s_dates.csv.gz'%(filedate)

# %%
## Bring in matplot lib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
## Bring in seaborn
import seaborn as sns

# %%
## Set coloring and background
plt.style.use('tableau-colorblind10')

# %%
## Make filename for saving figure
save_sat_OD = '../FIGURES/' + file_name.split('/')[-1
        ].split('.c')[0] + '_saturation_OD.png'

# %%
## Make a figure for pre culture saturation OD
fig,ax = plt.subplots(figsize=(12,2))
sns.boxplot(x='date',y='saturatedOD',
            data=data);
plt.xticks(rotation=90);
plt.ylabel('Pre-Culture\nSaturation OD')
if save_sat_OD is not None:
    plt.savefig(save_sat_OD,dpi=100,bbox_inches='tight');

# %%
data[(data.date=='Sep122018')].temp.unique()
# Out:
# array([39])

# %%
## What is the date of the batch effect?
bdate = 'Feb152018'

# %%
## Bring in numpy
import numpy as np

# %%
## Add batch code to each date
month_df['batched'] = [0 for i in np.arange(0,
    month_df[(month_df.date==bdate)].index[0])] + [1 for i in np.arange(
    month_df[(month_df.date==bdate)].index[0]+1,month_df.shape[0]+1)]

# %%
## save month dataframe
month_df.to_csv(month_df_save)

# %%
## Drop last 30 mins of data as it seems we don't have it for all data
data.drop(data.columns.tolist()[-2:],
          axis=1,inplace=True)

# %%
## Sort data one last time by temp, drug, and strain
data.sort_values(by=['temp','amphB','strain'],inplace=True)

# %%
## Reset the index
data.reset_index(inplace=True,drop=True)

# %%
## Check the shape one last time
data.shape
# Out:
# (5340, 298)

# %%
## Save data
data.to_csv('../FILES/'+file_name.split('/')[-1].split('.csv')[0]+'_curated.csv.gz')

# %%
## Plot replicates for DM at 39 with 0.0 amphB
htg = data[(data.temp==37) & (data.amphB==0.0)]

# %%
## What is its shape?
htg.shape
# Out:
# (600, 298)

# %%
## Gather the unique strains
uss = htg.strain.unique()

# %%
## Get unique dates in the high temp growth
htg_dates = htg.date.unique()

# %%
## Make a color map by date. How many are their?
len(htg_dates)
# Out:
# 9

# %%
## make color map
color_map = pd.DataFrame([('tab:blue','grey',
                           'tab:orange','purple',
                           'red','k','green','olive','navy'),
                          htg_dates],
                         index=['color','date']).T

# %%
color_map
# Out:
#         color       date
# 0    tab:blue  Sep182017
# 1        grey   Nov12017
# 2  tab:orange   Nov82017
# 3      purple  Feb212018
# 4         red  May252018
# 5           k  Sep122017
# 6       green   Oct42017
# 7       olive  Nov112017
# 8        navy  Apr142018

# %%
## Take the columns from the high temp growth 
htg_c = htg.columns.tolist()

# %%
## get the starting index of the time
timeix = htg_c.index('0s')

# %%
## Make a time vector
time = np.round(np.linspace(
    int(htg_c[timeix][:-1]),
    int(htg_c[-1][:-1])/(60**2),
    len(htg_c[timeix:])),2)

# %%
## Make filename for saving figure
htg_OD = '../FIGURES/' + file_name.split('/')[-1
        ].split('.c')[0] + '_htg39C_replicates.pdf'

# %%
timeix
# Out:
# 11

# %%
times = htg.columns.tolist()[timeix:]

# %%
test = pd.DataFrame(htg.groupby(['date','strain'])[times].max().max(axis=1)).reset_index()

# %%
test.columns = ['date','strain','maxOD']

# %%
sns.boxplot(x='date',y='maxOD',data=test);

# %%
htg.groupby('date')['plate'].min()
# Out:
# date
# Apr142018    1
# Feb212018    2
# May252018    1
# Nov112017    1
# Nov12017     2
# Nov82017     2
# Oct42017     1
# Sep122017    1
# Sep182017    2
# Name: plate, dtype: int64

# %%
htg.groupby('date')['plate'].max()
# Out:
# date
# Apr142018    1
# Feb212018    2
# May252018    2
# Nov112017    1
# Nov12017     2
# Nov82017     2
# Oct42017     1
# Sep122017    1
# Sep182017    2
# Name: plate, dtype: int64

# %%
htg[(htg.date=='Apr142018')].plate.unique()
# Out:
# array([1])

# %%
## Plot High temp growth for DM
fig, ax = plt.subplots(20,6,sharex=True,
                       sharey=True,
                       figsize=(12,35));
for i, s in enumerate(uss):
    plt.sca(ax.ravel()[i+1])
    temp = htg[(htg.strain==s)]
    for j in temp.index:
        mc = color_map[(color_map.date==temp.loc[j,
                    'date'])]['color'].values[0]
        plt.plot(time,temp.loc[j,htg_c[timeix:]],
                 color=mc,alpha=0.7)
    plt.title(s,y=0.8)
plt.sca(ax[0,0])
for i,date in enumerate(color_map['date'].values):
    plt.plot(0,np.nan,label=date,color=
             color_map[
                 (color_map.date==date)]
             ['color'].values[0])
plt.legend(bbox_to_anchor=(-.2,.9));
fig.text(0.5,0.1,'Time (hours)',
         fontsize=20,va='center',
         ha='center')
fig.text(0.075,0.5,'OD (600 um)',
         fontsize=30,va='center',ha='center',
         rotation=90);
plt.subplots_adjust(wspace=0.03,hspace=0.03)
#fig.savefig(htg_OD,dpi=150,bbox_inches='tight');
