# %%
# %matplotlib inline

# %%
import pandas as pd, numpy as np
from matplotlib import pyplot as plt

# %%
from PIL import Image

# %%
fludio = pd.read_csv('../../FILES/Cdx-predict-fludio-phenotype.csv')
fludio.drop(50,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e27a1cf56b6a> in <module>
# ----> 1 fludio = pd.read_csv('../../FILES/Cdx-predict-fludio-phenotype.csv')
#       2 fludio.drop(50,axis=0,inplace=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
image_path = '../../H2O2_fludioxonil/ypdqtl1andqtl2.png'

# %%
fludio[(fludio.Strain.isin(['XL280a','SS-A837']))]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 93   XL280a   0.0   0.0  Resistant   e       6  qtl2        1
# 94  SS-A837   1.0   1.0  Resistant   e       7  qtl2        1

# %%
im = Image.open(image_path)
#xl280a = im.crop([3190,660,3290,760])
xl280a = im.crop([1040,1975,1140,2075])
#xl280a.show()
xl280a.save('../../FIGURES/xl280a_e_6_001_ypd.png')

# %%
im = Image.open(image_path)
#_431 = im.crop([3330,660,3430,760])
_431 = im.crop([1180,1975,1280,2075])
#_431.show()
_431.save('../../FIGURES/431_e_7_111_ypd.png')

# %%
fludio[(fludio.Strain.isin(['SS-B307','SS-B314','SS-B311','SS-B310','SS-B317','SS-B369']))]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 5   SS-B369   0.0   1.0  Sensitive   b       7  qtl1        1
# 60  SS-B307   0.0   0.0  Resistant   b       2  qtl2        1
# 61  SS-B310   1.0   0.0  Resistant   b       4  qtl2        1
# 62  SS-B311   0.0   1.0  Sensitive   b       5  qtl2        0
# 65  SS-B314   1.0   1.0  Resistant   b       8  qtl2        1
# 68  SS-B317   0.0   1.0  Sensitive   b      11  qtl2        1

# %%
fludio[(fludio.Fludio=='Sensitive') & (fludio.Outcome!=0)]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 5   SS-B369   0.0   1.0  Sensitive   b       7  qtl1        1
# 6   SS-B373   0.0   1.0  Sensitive   b       8  qtl1        1
# 30  SS-B600   0.0   1.0  Sensitive   e       2  qtl1        1
# 68  SS-B317   0.0   1.0  Sensitive   b      11  qtl2        1
# 77  SS-B599   0.0   1.0  Sensitive   c      10  qtl2        1

# %%
im = Image.open(image_path)
#SSB307 = im.crop([2620,240,2720,340])
SSB307 = im.crop([475,1560,575,1660])
#SSB307.show()
SSB307.save('../../FIGURES/SSB307_b_2_001_ypd.png')

# %%
fludio[(fludio.SSK1==0) & (fludio.SSK2==1) & (fludio.Plate=='qtl2')].head()
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 62  SS-B311   0.0   1.0  Sensitive   b       5  qtl2        0
# 63  SS-B312   0.0   1.0  Sensitive   b       6  qtl2        0
# 64  SS-B313   0.0   1.0  Sensitive   b       7  qtl2        0
# 66  SS-B315   0.0   1.0  Sensitive   b       9  qtl2        0
# 68  SS-B317   0.0   1.0  Sensitive   b      11  qtl2        1

# %%
im = Image.open(image_path)
#SSB311 = im.crop([3050,240,3150,340])
SSB311 = im.crop([905,1550,1005,1650])
#SSB311.show()
SSB311.save('../../FIGURES/SSB311_b_5_010_ypd.png')

# %%
fludio[(fludio.SSK1==1) & (fludio.SSK2==1) & (fludio.Plate=='qtl2')].head()
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 65  SS-B314   1.0   1.0  Resistant   b       8  qtl2        1
# 90  SS-C290   1.0   1.0  Resistant   e       3  qtl2        1
# 91  SS-C291   1.0   1.0  Resistant   e       4  qtl2        1
# 94  SS-A837   1.0   1.0  Resistant   e       7  qtl2        1

# %%
im = Image.open(image_path)
#SSB314 = im.crop([3470,240,3570,340])
SSB314 = im.crop([1325,1560,1425,1660])
#SSB314.show()
SSB314.save('../../FIGURES/SSB314_b_8_111_ypd.png')

# %%
fludio[(fludio.SSK1==1) & (fludio.SSK2==0) & (fludio.Plate=='qtl2')].head()
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 61  SS-B310   1.0   0.0  Resistant   b       4  qtl2        1
# 69  SS-B350   1.0   0.0  Resistant   c       2  qtl2        1
# 70  SS-B354   1.0   0.0  Resistant   c       3  qtl2        1
# 72  SS-B382   1.0   0.0  Resistant   c       5  qtl2        1
# 73  SS-B383   1.0   0.0  Resistant   c       6  qtl2        1

# %%
im = Image.open(image_path)
#SSB310 = im.crop([2910,240,3010,340])
SSB310 = im.crop([755,1560,855,1660])
#SSB310.show()
SSB310.save('../../FIGURES/SSB310_b_4_101_ypd.png')

# %%
## Fludio

# %%
image_path = '../../H2O2_fludioxonil/fludioqtl1andqtl2c.png'

# %%
fludio[(fludio.Strain=='SS-A837')]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 94  SS-A837   1.0   1.0  Resistant   e       7  qtl2        1

# %%
im = Image.open(image_path)
#_431 = im.crop([3390,650,3490,750])
_431 = im.crop([1230,630,1330,730])
#_431.show()
_431.save('../../FIGURES/431_e_7_111_fludio.png')

# %%
fludio[(fludio.Strain=='XL280a')]
# Out:
#     Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 93  XL280a   0.0   0.0  Resistant   e       6  qtl2        1

# %%
im = Image.open(image_path)
#xl280 = im.crop([3250,650,3350,750])
xl280 = im.crop([1090,630,1190,730])
#xl280.show()
xl280.save('../../FIGURES/xl280_e_6_001_fludio.png')

# %%
fludio[(fludio.Strain=='SS-B307')]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 60  SS-B307   0.0   0.0  Resistant   b       2  qtl2        1

# %%
im = Image.open(image_path)
#SSB307 = im.crop([2680,230,2780,330])
SSB307 = im.crop([525,210,625,310])
#SSB307.show()
SSB307.save('../../FIGURES/SSB307_b_2_001_fludio.png')

# %%
fludio[(fludio.Strain=='SS-B311')]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 62  SS-B311   0.0   1.0  Sensitive   b       5  qtl2        0

# %%
im = Image.open(image_path)
#SSB311 = im.crop([3110,230,3210,330])
SSB311 = im.crop([950,210,1050,310])
#SSB311.show()
SSB311.save('../../FIGURES/SSB311_b_5_010_fludio.png')

# %%
fludio[(fludio.Strain=='SS-B314')]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 65  SS-B314   1.0   1.0  Resistant   b       8  qtl2        1

# %%
im = Image.open(image_path)
#SSB314 = im.crop([3530,230,3630,330])
SSB314 = im.crop([1370,210,1470,310])
#SSB314.show()
SSB314.save('../../FIGURES/SSB314_b_8_111_fludio.png')

# %%
fludio[(fludio.Strain=='SS-B310')]
# Out:
#      Strain  SSK1  SSK2     Fludio Row  Column Plate  Outcome
# 61  SS-B310   1.0   0.0  Resistant   b       4  qtl2        1

# %%
im = Image.open(image_path)
#SSB310 = im.crop([2960,230,3060,330])
SSB310 = im.crop([805,210,905,310])
#SSB310.show()
SSB310.save('../../FIGURES/SSB310_b_4_101_fludio.png')

# %%
import glob

# %%
fimp = sorted(glob.glob('../../FIGURES/*_*_*_fludio.png'))
fimp = [fimp[-1]] + fimp[:-1]
yimp = sorted(glob.glob('../../FIGURES/*_*_*_ypd.png'))
yimp = [yimp[-1]] + yimp[:-1]

# %%
fimp
# Out:
# ['../../FIGURES/xl280_e_6_001_fludio.png',
#  '../../FIGURES/431_e_7_111_fludio.png',
#  '../../FIGURES/SSB307_b_2_001_fludio.png',
#  '../../FIGURES/SSB310_b_4_101_fludio.png',
#  '../../FIGURES/SSB311_b_5_010_fludio.png',
#  '../../FIGURES/SSB314_b_8_111_fludio.png']

# %%
yimp
# Out:
# ['../../FIGURES/xl280a_e_6_001_ypd.png',
#  '../../FIGURES/431_e_7_111_ypd.png',
#  '../../FIGURES/SSB307_b_2_001_ypd.png',
#  '../../FIGURES/SSB310_b_4_101_ypd.png',
#  '../../FIGURES/SSB311_b_5_010_ypd.png',
#  '../../FIGURES/SSB314_b_8_111_ypd.png']

# %%
import matplotlib.image as mpimg

# %%
from matplotlib import rc
xl280al = 'XL280'+r'$\alpha$'#+'SS'
xl280a = 'XL280' +r'$\bf{a}$'
_431 = '431'+r'$\mathrm{\alpha}$'
#segs = [s for s in geno_strains 
#        if s not in parentals]

# %%
genox_outcomes = [a.split('_')[-2] for a in yimp]

# %%
genos = [ (int(a[0]),int(a[1])) for a in  genox_outcomes]

# %%
genos
# Out:
# [(0, 0), (1, 1), (0, 0), (1, 0), (0, 1), (1, 1)]

# %%
import cv2

# %%
ssk1d = 'ssk1\Delta'#'$\it{ssk1\Delta}$'
ssk1 = 'SSK1'#'$\it{SSK1}$'

ssk2d = 'ssk2\Delta'#'$\it{ssk2\Delta}$'
ssk2 = 'SSK2'#'$\it{SSK2}$'

# %%
SSK1 = (ssk1,ssk1d)
SSK2 = (ssk2,ssk2d)

# %%
ssk1_ssk2 = [ (SSK1[g[0]],SSK2[g[1]]) for g in genos]

# %%
ssk1_ssk2
# Out:
# [('SSK1', 'SSK2'),
#  ('ssk1\\Delta', 'ssk2\\Delta'),
#  ('SSK1', 'SSK2'),
#  ('ssk1\\Delta', 'SSK2'),
#  ('SSK1', 'ssk2\\Delta'),
#  ('ssk1\\Delta', 'ssk2\\Delta')]

# %%
fontsize = 10

# %%
fimp
# Out:
# ['../../FIGURES/xl280_e_6_001_fludio.png',
#  '../../FIGURES/431_e_7_111_fludio.png',
#  '../../FIGURES/SSB307_b_2_001_fludio.png',
#  '../../FIGURES/SSB310_b_4_101_fludio.png',
#  '../../FIGURES/SSB311_b_5_010_fludio.png',
#  '../../FIGURES/SSB314_b_8_111_fludio.png']

# %%
import glob

# %%
xl280a = 'XL280' +r'$\bf{a}$'
_431 = r'$\rm431$'+r'$\mathrm{\alpha}$'
kn99 = 'KN99' +r'$\mathrm{\alpha}$'
ric8 = 'ric8' + '$\Delta$'#'$\it{ric8\Delta}$'
strains = [kn99,ric8,_431,xl280a]

# %%
glob.glob('../../FIGURES/*_cAMP.png')
# Out:
# ['../../FIGURES/Ric8_phenotyping_cAMP.png',
#  '../../FIGURES/Cdx_L-DOPA_L-DOPA_cAMP.png',
#  '../../FIGURES/XL280a_cAMP.png',
#  '../../FIGURES/ric8_cAMP.png',
#  '../../FIGURES/Kn99a_cAMP.png',
#  '../../FIGURES/431_cAMP.png']

# %%
_ldopa = np.array(sorted(glob.glob('../../FIGURES/*_ldopa.png')))[[1,3,0,2]]
_cAMP = np.array(sorted(glob.glob('../../FIGURES/*_cAMP.png')[2:]))[[1,3,0,2]]

# %%
assert len(_cAMP) == len(_ldopa)

# %%
htg = pd.read_csv('/Users/croth/Downloads/KN99_ric8_htg.csv')
ghtg = [g for g in htg.groupby(['strain','temp'])]

timeix = htg.columns.tolist().index('0s')
time_cols = htg.columns[timeix:]
time_min = [int(a[:-1])/(60**2) for a in time_cols]

# %%
pd.crosstab(fludio.SSK1,[fludio.SSK2,fludio.Outcome])
# Out:
# SSK2    0.0 1.0
# Outcome   1   0   1
# SSK1
# 0.0      28  14   6
# 1.0      37   0  19

# %%
fontsize=12
Y  = .6
fig,ax = plt.subplots(1,1,figsize=(9,5),facecolor='w')
for i,j in enumerate(yimp): ## Plot YPD
    axey = fig.add_axes([.45,Y-(i*.11),0.05,.1])
    plt.sca(axey)
    plt.title('YPD\n' if i == 0 else None,fontsize=fontsize)
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    strain = j.split('/')[-1].split('_')[0]
    if strain == '431':
        strain = _431
    elif strain == 'xl280a':
        strain = xl280a
    else:
        pass
    
for i,j in enumerate(fimp): ## Plot Fludio
    axef = fig.add_axes([0.55,Y-(i*.11),0.05,.1])
    plt.sca(axef)
    plt.title('Fludioxonil\n100 $\mu$g/ml' if i == 0 else None,fontsize=fontsize)
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')

for i,g in enumerate(genos): ## Write genotypes by allele
    axeg1 = fig.add_axes([0.30,Y-(i*.11),0.05,.1])
    
    #plt.text(-3,2.5,'A' if i == 0 else None, 
    #         transform = axeg1.transAxes,
    #         va='center',ha='center',
    #         fontsize=fontsize,
    #         fontweight='bold', color='k')
    
    plt.sca(axeg1)
    plt.title('SSK1\n' + r'$\rmAllele$' if i == 0 else None,fontsize=fontsize,style='italic')
    sg = g[0]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform = axeg1.transAxes,
             va='center',ha='center',fontsize=fontsize-2,color=cl)
    plt.axis('off')
    
    axeg2 = fig.add_axes([0.38,Y-(i*.11),0.05,.1])
    plt.sca(axeg2)
    plt.title('SSK2\n' + r'$\rmAllele$' if i == 0 else None,fontsize=fontsize,style='italic')
    sg = g[1]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform = axeg2.transAxes,
             va='center',ha='center',fontsize=fontsize-2,color=cl)
    plt.axis('off')
    
nos = ['-','-',28,37,6,19]
fs = ['-','-',0,0,14,0]

for i,k in enumerate(nos): ## Number of resistant
    axnr = fig.add_axes([0.66,Y-(i*.11),0.05,.1])
    plt.sca(axnr)
    plt.title('# of\nResistant' if i == 0 else None,fontsize=fontsize)
    plt.text(0.5,0.5,k, transform=axnr.transAxes,
             va='center',ha='center',fontsize=12)
    plt.axis('off')
    
    
for i,k in enumerate(fs): ## Number of sensitive
    axns = fig.add_axes([0.76,Y-(i*.11),0.05,.1])
    plt.sca(axns)
    plt.title('# of\nSensitive' if i == 0 else None,fontsize=fontsize)
    plt.text(0.5,0.5,k, transform=axns.transAxes,
             va='center',ha='center',fontsize=12)
    plt.axis('off')
    
X = .25
axes= fig.add_axes([X,Y-.53,0.04,.39])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.75,0.5,'Progeny\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=fontsize);
axes.set_xticks([]);

axes= fig.add_axes([X,Y-.08,0.04,.16])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.75,0.5,'Parental\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=fontsize);
axes.set_xticks([]);
plt.sca(ax);plt.axis('off');
mydpi=600
plos_save = '/Users/croth/QTL_FIGS/MAIN/Fig8.tiff'
plt.savefig(plos_save,
           dpi=mydpi,bbox_inches='tight',figsize=(5,2));

im = Image.open(plos_save)
w,h = im.size
assert w/mydpi < 7.5
assert h/mydpi < 8

im.save(plos_save,compression='tiff_lzw')
# Out:
# /Users/croth/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:105: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "figsize" which is no longer supported as of 3.3 and will become an error two minor releases later

# %%
fontsize=14
Y  = .55
fig,ax = plt.subplots(4,2,figsize=(4,4))
#plt.sca(ax);plt.axis('off')
for i in range(4):
    ## L-DOPA
    plt.sca(ax[i,0]);plt.axis('off')

    j = _ldopa[i]
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.text(-1,.5,strains[i],transform=ax[i,0].transAxes,
             va='center',ha='center',fontsize=fontsize)
    plt.title('L-DOPA\n' if i ==0 else None,fontsize=fontsize)
    ## L-DOPA+cAMP
    plt.sca(ax[i,1])

    j = _cAMP[i]
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title('L-DOPA\n+ cAMP' if i == 0 else None,fontsize=fontsize)
plt.subplots_adjust(wspace=-0.65)
#plt.savefig('../../FIGURES/Cdx_L-DOPA.png',
#           dpi=200,bbox_inches='tight');

# %%
xl280a = r'$\rm XL280$' + r'$\bf{a}$'
_431 = r'$\rm431$'+r'$\mathrm{\alpha}$'
kn99 = r'$\rmKN99$' +r'$\mathrm{\alpha}$'
ric8 = 'ric8' + '$\Delta$'#'$\it{ric8\Delta}$'
strains = [kn99,ric8,_431,xl280a]

# %%
fontsize=14
Y  = .55
fig,ax = plt.subplots(1,1,figsize=(8,5),facecolor='w')
plt.sca(ax);plt.axis('off')
for i in range(4):
    ## L-DOPA
    axld = fig.add_axes([0.25,Y-(i*.11),0.05,.1])
    plt.sca(axld);plt.axis('off')
    plt.text(-2,2.5,'A' if i == 0 else None, 
             transform = axld.transAxes,
             va='center',ha='center',
             fontsize=fontsize,
             fontweight='bold', color='k')
    j = _ldopa[i]
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.text(-1.2,0.5,strains[i],transform=axld.transAxes,
             va='center',ha='center',fontsize=fontsize,style='italic')
    plt.title('L-DOPA\n' if i ==0 else None,fontsize=fontsize)
    ## L-DOPA+cAMP
    axlc = fig.add_axes([0.35,Y-(i*.11),0.05,.1])
    plt.sca(axlc)
    plt.text(4,2.5,'B' if i == 0 else None, 
             transform = axld.transAxes,
             va='center',ha='center',
             fontsize=fontsize,
             fontweight='bold', color='k')
    j = _cAMP[i]
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title('L-DOPA\n+ cAMP' if i == 0 else None,fontsize=fontsize)

#ax37 = fig.add_axes([1.07, Y-.13, 0.15, .2])
#ax39 = fig.add_axes([1.07, Y-.47, 0.15, .2])
ax37 = fig.add_axes([.5, Y-.2, 0.15, .2])
ax39 = fig.add_axes([.7, Y-.2, 0.15, .2])
z = 1.96
for i,((gene,k),d) in enumerate(ghtg):
    if k == 37:
        plt.sca(ax37)
        plt.ylabel('OD',fontsize=fontsize-2);
        plt.xlabel(u'Hours at\n%s°C'%(k),fontsize=fontsize-2);
    else:
        assert k == 39
        plt.sca(ax39)
        #plt.ylabel('OD',fontsize=fontsize-2);
        plt.xlabel(u'Hours at\n%s°C'%(k),fontsize=fontsize-2);
    
    m = d[time_cols].mean().values
    std = d[time_cols].std(ddof=1).values
    
    ci95_hi = m + ((z*std)/np.math.sqrt(d.shape[0]))
    ci95_lo = m - ((z*std)/np.math.sqrt(d.shape[0]))
        
    plt.fill_between(time_min, ci95_hi, ci95_lo, 
            alpha=0.25, color = 'r' if gene[0]=='C' else 'k')
    
    
    plt.plot(time_min, m, 
             color = 'r' if gene[0]=='C' else 'k',
             alpha = 0.5,
             label = ric8 if (k==37) and (gene[0] == 'C') else kn99)
    plt.xticks([12,36,60],fontsize=fontsize-2);
    plt.ylim(0,1);plt.yticks([0,0.5,1.0],fontsize=fontsize-2);
plt.sca(ax37);
plt.legend(bbox_to_anchor = (1.6,2.15),
           frameon=False,prop=dict(zip(['style','size'],['italic',fontsize])));
ax37.spines['right'].set_visible(False)
ax37.spines['top'].set_visible(False)
ax39.spines['right'].set_visible(False)
ax39.spines['top'].set_visible(False)

mydpi = 600
plos_path = '/Users/croth/QTL_FIGS/MAIN/Fig7.tiff'
plt.savefig(plos_path,
           dpi=mydpi,bbox_inches='tight');

im = Image.open(plos_path)
w,h = im.size
assert w/mydpi < 7.5 
assert h/mydpi < 8.5

im.save(plos_path,compression='tiff_lzw');

# %%
htg['AUC'] = htg[time_cols].T.sum()*.25
htg['MaxOD'] = htg[time_cols].T.max()

# %%
import seaborn as sns, statsmodels.formula.api as smf

# %%
sns.boxplot(x='strain',y='MaxOD',hue='temp',data=htg);

# %%
htg.MaxOD.hist();

# %%
smf.ols('MaxOD~strain+temp',data=htg).fit().summary()
# Out:
# /Users/croth/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1604: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  MaxOD   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     34.55
# Date:                Tue, 25 Aug 2020   Prob (F-statistic):           6.27e-06
# Time:                        18:23:45   Log-Likelihood:                 21.731
# No. Observations:                  16   AIC:                            -37.46
# Df Residuals:                      13   BIC:                            -35.14
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
ssk1_allele = [ssk1,ssk1d,ssk1,ssk1d]
ssk1_parent = [xl280a,_431,xl280a,_431]
ssk2_allele = [ssk2,ssk2,ssk2d,ssk2d]
ssk2_parent = [xl280a,xl280a,_431,_431]

# %%
fine_map_res = pd.read_csv('../../FILES/Cdx_Fine_map_fludio_res.csv',index_col=0)
fig,ax = plt.subplots(4,4,figsize=(6,4))
J = 0
plt.sca(ax[0,J]);plt.title('SSK1\n'+r'$\rmAllele$',fontsize=14,style='italic')
for i,k in enumerate(ssk1_allele):
    plt.sca(ax[i,J])
    mc = 'tab:blue' if ssk1_parent[i][5] == 'X' else 'tab:orange'
    plt.text(0.5,0.5,ssk1_parent[i],#+'$_{\it{%s}}$'%(k), 
             transform=ax[i,J].transAxes,
             va='center',ha='center',
             fontsize=14,color=mc)
    plt.axis('off')
J = 1
plt.sca(ax[0,J]);plt.title('SSK2\n'+r'$\rmAllele$',fontsize=14,style='italic')
for i,k in enumerate(ssk2_allele):
    plt.sca(ax[i,J])
    mc = 'tab:blue' if ssk2_parent[i][5] == 'X' else 'tab:orange'
    plt.text(0.5,0.5,ssk2_parent[i],#+'$_{\it{%s}}$'%(k), 
             transform=ax[i,J].transAxes,
             va='center',ha='center',
             fontsize=14,color=mc)
    plt.axis('off')
    
nos = [20,7,10,6]
fs = [0,0,130,0]
for i,k in enumerate(nos):
    plt.sca(ax[i,-2])
    plt.text(0.5,0.5,k, transform=ax[i,-2].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    

for i,k in enumerate(fs):
    plt.sca(ax[i,-1])
    plt.text(0.5,0.5,k, transform=ax[i,-1].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
plt.sca(ax[0,2]);plt.title('# of\nResistant',fontsize=14)
plt.sca(ax[0,3]);plt.title('# of\nSensitive',fontsize=14);
plt.subplots_adjust(wspace=0.01)
axt = fig.add_axes([.14, 1.02, .77, .0002]);plt.xticks([]);plt.yticks([])
axt = fig.add_axes([.14, .87, .77, .0002]);plt.xticks([]);plt.yticks([])
axt = fig.add_axes([.14, .162, .77, .0002]);plt.xticks([]);plt.yticks([])


#plt.savefig('../../FIGURES/Cdx_Finemap_Fludio_Results.png',
plt.savefig('/Users/croth/QTL_FIGS/SUPP/FIGS/S19_Fig.pdf',
               dpi=300,bbox_inches='tight');

# %%
assert 1 == 0

# %%
fontsize=14
fig,ax = plt.subplots(1,1,figsize=(10,5))
for i,j in enumerate(yimp): ## Plot YPD
    axey = fig.add_axes([0.3,.80-(i*.11),0.05,.1])
    plt.sca(axey)
    plt.title('YPD\n' if i == 0 else None,fontsize=fontsize)
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    strain = j.split('/')[-1].split('_')[0]
    if strain == '431':
        strain = _431
    elif strain == 'xl280a':
        strain = xl280a
    else:
        pass
    
for i,j in enumerate(fimp): ## Plot Fludio
    axef = fig.add_axes([0.39,.80-(i*.11),0.05,.1])
    plt.sca(axef)
    plt.title('Fludioxonil\n100 $\mu$g/ml' if i == 0 else None,fontsize=fontsize)
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')

for i,g in enumerate(genos): ## Write genotypes by allele
    axeg1 = fig.add_axes([0.16,.80-(i*.11),0.05,.1])
    
    plt.text(-3,2.5,'A' if i == 0 else None, 
             transform = axeg1.transAxes,
             va='center',ha='center',
             fontsize=fontsize,
             fontweight='bold', color='k')
    
    plt.sca(axeg1)
    plt.title('$SSK1$\nAllele' if i == 0 else None,fontsize=fontsize)
    sg = g[0]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform = axeg1.transAxes,
             va='center',ha='center',fontsize=fontsize-2,color=cl)
    plt.axis('off')
    
    axeg2 = fig.add_axes([0.23,.80-(i*.11),0.05,.1])
    plt.sca(axeg2)
    plt.title('$SSK2$\nAllele' if i == 0 else None,fontsize=fontsize)
    sg = g[1]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform = axeg2.transAxes,
             va='center',ha='center',fontsize=fontsize-2,color=cl)
    plt.axis('off')
    
nos = ['-','-',28,37,5,18]
fs = ['-','-',0,0,14,0]

for i,k in enumerate(nos): ## Number of resistant
    axnr = fig.add_axes([0.5,.80-(i*.11),0.05,.1])
    plt.sca(axnr)
    plt.title('# of\nResistant' if i == 0 else None,fontsize=fontsize)
    plt.text(0.5,0.5,k, transform=axnr.transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
    
for i,k in enumerate(fs): ## Number of sensitive
    axns = fig.add_axes([0.6,.80-(i*.11),0.05,.1])
    plt.sca(axns)
    plt.title('# of\nSensitive' if i == 0 else None,fontsize=fontsize)
    plt.text(0.5,0.5,k, transform=axns.transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
X = 0.11
axes= fig.add_axes([X,0.27,0.04,.39])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.75,0.5,'Progeny\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=fontsize);
axes.set_xticks([]);

axes= fig.add_axes([X,0.72,0.04,.16])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.75,0.5,'Parental\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=fontsize);
axes.set_xticks([]);
plt.sca(ax);plt.axis('off');


for i in range(4):
    ## L-DOPA
    axld = fig.add_axes([0.82,.80-(i*.11),0.05,.1])
    plt.sca(axld);plt.axis('off')
    plt.text(-2,2.5,'B' if i == 0 else None, 
             transform = axld.transAxes,
             va='center',ha='center',
             fontsize=fontsize,
             fontweight='bold', color='k')
    j = _ldopa[i]
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.text(-1.2,0.5,strains[i],transform=axld.transAxes,
             va='center',ha='center',fontsize=fontsize)
    plt.title('L-DOPA\n' if i ==0 else None,fontsize=fontsize)
    ## L-DOPA+cAMP
    axlc = fig.add_axes([0.91,.80-(i*.11),0.05,.1])
    plt.sca(axlc)
    plt.text(4,2.5,'C' if i == 0 else None, 
             transform = axld.transAxes,
             va='center',ha='center',
             fontsize=fontsize,
             fontweight='bold', color='k')
    j = _cAMP[i]
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title('L-DOPA\n+ cAMP' if i == 0 else None,fontsize=fontsize)

ax37 = fig.add_axes([1.07, .67, 0.15, .2])
ax39 = fig.add_axes([1.07, .33, 0.15, .2])
for i,((gene,k),d) in enumerate(ghtg):
    if k == 37:
        plt.sca(ax37)
        plt.ylabel('OD',fontsize=fontsize-2);
        plt.xlabel(u'Hours at %s°C'%(k),fontsize=fontsize-2);
    else:
        assert k == 39
        plt.sca(ax39)
        plt.ylabel('OD',fontsize=fontsize-2);
        plt.xlabel(u'Hours at %s°C'%(k),fontsize=fontsize-2);
    plt.plot(time_min, d[time_cols].mean().values, 
             color = 'r' if gene[0]=='C' else 'k',
             alpha = 0.5,
             label = ric8 if (k==37) and (gene[0] == 'C') else kn99)
    plt.xticks([12,36,60],fontsize=fontsize-2);
    plt.ylim(0,1);plt.yticks([0,0.5,1.0],fontsize=fontsize-2);
plt.sca(ax37);
plt.legend(bbox_to_anchor = (1.2,1.75),
           frameon=False,fontsize=fontsize);
ax37.spines['right'].set_visible(False)
ax37.spines['top'].set_visible(False)
ax39.spines['right'].set_visible(False)
ax39.spines['top'].set_visible(False)
plt.savefig('../../FIGURES/Cdx_Fludio_L-DOPA_HTG.png',
           dpi=200,bbox_inches='tight',figsize=(8,3));

# %%
assert 1 == 0

# %%
plt.plot(time_min,ghtg[0][1][time_cols].mean().values);

# %%
fig,ax = plt.subplots(6,6,figsize=(6,4))
J = 2
plt.sca(ax[0,J])
plt.title('YPD\n',fontsize=fontsize)
for i,j in enumerate(yimp):
    plt.sca(ax[i,J])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    strain = j.split('/')[-1].split('_')[0]
    if strain == '431':
        strain = _431
    elif strain == 'xl280a':
        strain = xl280a
    else:
        pass   
J = 3
plt.sca(ax[0,J])
plt.title('Fludioxonil\n100 $\mu$g/ml',fontsize=fontsize)
for i,j in enumerate(fimp):
    plt.sca(ax[i,J])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')

for i,g in enumerate(genos):
    plt.sca(ax[i,0])
    sg = g[0]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform=ax[i,0].transAxes,
             va='center',ha='center',fontsize=11,color=cl)
    plt.axis('off')
    plt.sca(ax[i,1])
    sg = g[1]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform=ax[i,1].transAxes,
             va='center',ha='center',fontsize=11,color=cl)
    plt.axis('off')
plt.sca(ax[0,0]);plt.title('$SSK1$\nAllele',fontsize=fontsize)
plt.sca(ax[0,1]);plt.title('$SSK2$\nAllele',fontsize=fontsize)

ssk1_allele = [ssk1,ssk1d,ssk1,ssk1d]
ssk1_parent = [xl280a,_431,xl280a,_431]
ssk2_allele = [ssk2,ssk2,ssk2d,ssk2d]
ssk2_parent = [xl280a,xl280a,_431,_431]

plt.sca(ax[0,-2]);plt.title('# of\nResistant',fontsize=fontsize)
plt.sca(ax[0,-1]);plt.title('# of\nSensitive',fontsize=fontsize)


    
nos = [1,1,28,37,5,18]
nos = ['-','-',28,37,5,18]
fs = [0,0,0,0,14,0]
fs = ['-','-',0,0,14,0]

for i,k in enumerate(nos):
    plt.sca(ax[i,-2])
    plt.text(0.5,0.5,k, transform=ax[i,-2].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
    
for i,k in enumerate(fs):
    plt.sca(ax[i,-1])
    plt.text(0.5,0.5,k, transform=ax[i,-1].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    

X = 0.09
axes= fig.add_axes([X,0.15,0.04,.45])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.75,0.5,'Progeny\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=fontsize);
axes.set_xticks([]);

axes= fig.add_axes([X,0.66,0.04,.21])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.75,0.5,'Parental\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=fontsize);
axes.set_xticks([]);

plt.subplots_adjust(hspace=0.1,wspace=0.001);
plt.savefig('../../FIGURES/Cdx_Fludio_Results.png',
            dpi=150,bbox_inches='tight');

# %%
assert 1 == 0

# %%
fig,ax = plt.subplots(6,9,figsize=(9,4))
J = 2
plt.sca(ax[0,J])
plt.title('YPD\n',fontsize=12)
for i,j in enumerate(yimp):
    plt.sca(ax[i,J])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    strain = j.split('/')[-1].split('_')[0]
    if strain == '431':
        strain = _431
    elif strain == 'xl280a':
        strain = xl280a
    else:
        pass   
J = 3
plt.sca(ax[0,J])
plt.title('Fludioxonil\n100 $\mu$g/ml',fontsize=12)
for i,j in enumerate(fimp):
    plt.sca(ax[i,J])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')

for i,g in enumerate(genos):
    plt.sca(ax[i,0])
    sg = g[0]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform=ax[i,0].transAxes,
             va='center',ha='center',fontsize=11,color=cl)
    plt.axis('off')
    plt.sca(ax[i,1])
    sg = g[1]
    if sg == 0:
        s = xl280a
        cl = 'tab:blue'
    else:
        assert sg == 1
        s = _431
        cl = 'tab:orange'
    plt.text(0.5,0.5,s, transform=ax[i,1].transAxes,
             va='center',ha='center',fontsize=11,color=cl)
    plt.axis('off')
plt.sca(ax[0,0]);plt.title('$SSK1$\nAllele',fontsize=12)
plt.sca(ax[0,1]);plt.title('$SSK2$\nAllele',fontsize=12)
axes= fig.add_axes([.5,0.1,0.01,.9])
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.spines['bottom'].set_visible(False)
axes.set_yticks([])
axes.set_xticks([])
ssk1_allele = [ssk1,ssk1d,ssk1,ssk1d]
ssk1_parent = [xl280a,_431,xl280a,_431]
ssk2_allele = [ssk2,ssk2,ssk2d,ssk2d]
ssk2_parent = [xl280a,xl280a,_431,_431]
J = -4
for i,k in enumerate(ssk1_parent):
    if k[0] == 'X':
        cl = 'tab:blue'
    else:
        assert k[0] == '4'
        cl = 'tab:orange'
    plt.text(0.5,0.5,k, transform=ax[i,J].transAxes,
             va='center',ha='center',fontsize=11,color=cl)
    plt.sca(ax[i,J])
    plt.axis('off')
plt.sca(ax[0,J]);plt.title('$SSK1$\nAllele',fontsize=12)
plt.sca(ax[0,-2]);plt.title('# of\nResistant',fontsize=12)
J = -3
for i,k in enumerate(ssk2_parent):

    plt.sca(ax[i,J])
    plt.axis('off')
plt.sca(ax[0,J]);plt.title('$SSK2$\nAllele',fontsize=12)
plt.sca(ax[0,-1]);plt.title('# of\nSensitive',fontsize=12)

plt.subplots_adjust(wspace=0.75);

for i in range(len(yimp)):
    plt.sca(ax[i,-5]);plt.axis('off')
    
for i in np.arange(1,5):
    plt.sca(ax[-1,-i]);plt.axis('off')
    plt.sca(ax[-2,-i]);plt.axis('off')
    
nos = [29,37,5,19]
fs = [0,0,14,0]
for i,k in enumerate(nos):
    plt.sca(ax[i,-2])
    plt.text(0.5,0.5,k, transform=ax[i,-2].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
    
for i,k in enumerate(fs):
    plt.sca(ax[i,-1])
    plt.text(0.5,0.5,k, transform=ax[i,-1].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
plt.text(-3.5,3,'A', transform=ax[0,0].transAxes,
             va='center',ha='center',
         fontsize=14,fontweight='bold');
plt.text(-0.7,3,'B', transform=ax[0,5].transAxes,
             va='center',ha='center',
         fontsize=14,fontweight='bold');
X = 0.07
axes= fig.add_axes([X,0.15,0.04,.45])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.5,0.5,'Progeny\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=12);
axes.set_xticks([]);

axes= fig.add_axes([X,0.66,0.04,.21])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
plt.text(-1.5,0.5,'Parental\nGenotypes', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=12);
axes.set_xticks([]);
#plt.savefig('../../FIGURES/Cdx_Fludio_Results.png',
#            dpi=150,bbox_inches='tight');

# %%
nos = [29,37,5,19]
fs = [0,0,14,0]
ssk1_ssk2_df = pd.DataFrame([list(np.arange(4))+list(np.arange(4)),
                             nos+fs,list(np.zeros(4))+list(np.ones(4))],
                           index=['SSK','Number','Fludio']).T

# %%
ssk1_ssk2_df['Fludio'].replace(dict(zip([0,1],['Resistant','Sensitive'])),inplace=True)

# %%
import seaborn as sns

# %%
fig,ax = plt.subplots(4,6,figsize=(7,4))
axes = fig.add_axes([0.39,.8,.5,.6])
sns.barplot(x='SSK',y='Number',hue='Fludio',
            data=ssk1_ssk2_df,ax=axes);
plt.xlabel(' ')
plt.xticks(np.arange(4),labels=' ')
plt.ylabel('Number of Progeny',fontsize=14)
plt.legend(fontsize=14)
plt.text(-0.5,0.1,'$\it{SSK1}$',
         transform = ax[0,0].transAxes,
         va='center', ha='center',fontsize=14)
plt.text(-0.5,0.5,'$\it{SSK2}$',
         transform = ax[1,0].transAxes,
        va='center', ha='center',fontsize=14)
plt.text(-0.8,0.5,'YPD',
         transform = ax[3,0].transAxes,
        va='center', ha='center',fontsize=14)
plt.text(-0.8,0.5,'Fludioxonil\n100 $\mu$g/ml',
         transform = ax[2,0].transAxes,
        va='center', ha='center',fontsize=14)

for i,g in enumerate(genos):
    plt.sca(ax[0,i])
    sg = g[0]
    if sg == 0:
        s = xl280a
    else:
        assert sg == 1
        s = _431
    plt.text(0.5,0.1,s, transform=ax[0,i].transAxes,
             va='center',ha='center',fontsize=11)
    plt.axis('off')
    plt.sca(ax[1,i])
    sg = g[1]
    if sg == 0:
        s = xl280a
    else:
        assert sg == 1
        s = _431
    plt.text(0.5,0.5,s, transform=ax[1,i].transAxes,
             va='center',ha='center',fontsize=11)
    plt.axis('off')


for i,j in enumerate(fimp):
    plt.sca(ax[2,i])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
for i,j in enumerate(yimp):
    plt.sca(ax[3,i])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
plt.subplots_adjust(wspace=0.01,hspace=0.1)
axes= fig.add_axes([0.39,0.05,0.51,.05])
plt.yticks([],labels=' ')
plt.xticks([0.5],labels=' ')
plt.xlabel('F2\nProgeny',fontsize=14)
axes.spines['top'].set_visible(False)

axes= fig.add_axes([0.13,0.05,0.25,.05])
plt.yticks([],labels=' ')
plt.xticks([0.5],labels=' ')
plt.xlabel('Parental\nStrains',fontsize=14)
axes.spines['top'].set_visible(False)

# %%
fig,ax = plt.subplots(6,8,figsize=(9,4))
for i,j in enumerate(yimp):
    plt.sca(ax[i,1])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    strain = j.split('/')[-1].split('_')[0]
    if strain == '431':
        strain = _431
    elif strain == 'xl280a':
        strain = xl280a
    else:
        pass
    #sp = "%s_{%s,%s}"%(strain,ssk1_ssk2[i][0],ssk1_ssk2[i][1])
    plt.text(-0.2,0.5, strain + '$_{\it{%s, %s}}$'%(ssk1_ssk2[i][0],ssk1_ssk2[i][1]), 
             transform=ax[i,0].transAxes,
             va='center',ha='center',fontsize=14)
    #plt.text(0.8,0.15, '$\it{%s, %s}$'%(ssk1_ssk2[i][0],ssk1_ssk2[i][1]), transform=ax[i,0].transAxes,
    #         va='center',ha='center',fontsize=10)#, style='italic')
    plt.sca(ax[i,0]);plt.axis('off')
    
plt.sca(ax[0,1])
plt.title('YPD\n',fontsize=12)
plt.sca(ax[0,2])
plt.title('Fludioxonil\n100 $\mu$g/ml',fontsize=12)
for i,j in enumerate(fimp):
    plt.sca(ax[i,2])
    #im =  mpimg.imread(j)
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    #plt.imshow(im)#,cmap='gray')
    plt.axis('off')


axes= fig.add_axes([.45,0.1,0.01,.9])
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.spines['bottom'].set_visible(False)
axes.set_yticks([])
axes.set_xticks([])
plt.sca(ax[0,4]);plt.title('$SSK1$\nAllele',fontsize=12)
plt.sca(ax[0,5]);plt.title('$SSK2$\nAllele',fontsize=12)
ssk1_allele = [ssk1,ssk1d,ssk1,ssk1d]
ssk1_parent = [xl280a,_431,xl280a,_431]
ssk2_allele = [ssk2,ssk2,ssk2d,ssk2d]
ssk2_parent = [xl280a,xl280a,_431,_431]
J = 4
for i,k in enumerate(ssk1_allele):
    plt.sca(ax[i,J])
    plt.text(0.2,0.5,ssk1_parent[i]+'$_{\it{%s}}$'%(k), transform=ax[i,J].transAxes,
             va='center',ha='center',fontsize=11)
    plt.axis('off')
J = 5
for i,k in enumerate(ssk2_allele):
    plt.sca(ax[i,J])
    plt.text(0.5,0.5,ssk2_parent[i]+'$_{\it{%s}}$'%(k), transform=ax[i,J].transAxes,
             va='center',ha='center',fontsize=11)
    plt.axis('off')
#plt.sca(ax[0,7]);plt.title('Number of\nSegregants',fontsize=10)
plt.sca(ax[0,6]);plt.title('# of\nResistant',fontsize=12)
plt.sca(ax[0,7]);plt.title('# of\nSensitive',fontsize=12)
#plt.text(1.5,1.5,'Number of Se')
#plt.sca(ax[0,8]);plt.title('Fludioxonil\nSusceptible',fontsize=10)
plt.subplots_adjust(wspace=0.75);

for i in range(len(yimp)):
    plt.sca(ax[i,3]);plt.axis('off')
    
for i in np.arange(4,8,1):
    plt.sca(ax[-1,i]);plt.axis('off')
    plt.sca(ax[-2,i]);plt.axis('off')
    
#nos = [29,19,37,5]
nos = [29,37,5,19]
#fs = [0,0,0,14]
fs = [0,0,14,0]
for i,k in enumerate(nos):
    plt.sca(ax[i,-2])
    plt.text(0.5,0.5,k, transform=ax[i,-2].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
    
for i,k in enumerate(fs):
    plt.sca(ax[i,-1])
    plt.text(0.5,0.5,k, transform=ax[i,-1].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
plt.text(-5,3,'A', transform=ax[0,0].transAxes,
             va='center',ha='center',
         fontsize=14,fontweight='bold');
plt.text(-0.7,3,'B', transform=ax[0,4].transAxes,
             va='center',ha='center',
         fontsize=14,fontweight='bold');
#plt.subplots_adjust(wspace=0.1)
axes= fig.add_axes([-0.03,0.15,0.04,.45])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
#plt.ylabel('Representitive\nProgeny')
plt.text(-2,0.5,'Representitive\nProgeny', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=12);
axes.set_xticks([]);

axes= fig.add_axes([-0.03,0.66,0.04,.21])
axes.spines['right'].set_visible(False)
plt.yticks([0.5],labels=[])
#plt.ylabel('Parental\nStrains')
plt.text(-2,0.5,'Parental\nStrains', 
         transform=axes.transAxes,
             va='center',ha='center',fontsize=12);
axes.set_xticks([]);
#plt.savefig('../../FIGURES/Cdx_Fludio_Results.png',
#            dpi=150,bbox_inches='tight');

# %%
fine_map_res

# %%
fine_map_res = pd.read_csv('../../FILES/Cdx_Fine_map_fludio_res.csv',index_col=0)
fig,ax = plt.subplots(4,4,figsize=(6,4))
J = 0
plt.sca(ax[0,J]);plt.title('$SSK1$\nAllele',fontsize=14)
for i,k in enumerate(ssk1_allele):
    plt.sca(ax[i,J])
    mc = 'tab:blue' if ssk1_parent[i][0] == 'X' else 'tab:orange'
    plt.text(0.5,0.5,ssk1_parent[i],#+'$_{\it{%s}}$'%(k), 
             transform=ax[i,J].transAxes,
             va='center',ha='center',
             fontsize=14,color=mc)
    plt.axis('off')
J = 1
plt.sca(ax[0,J]);plt.title('$SSK2$\nAllele',fontsize=14)
for i,k in enumerate(ssk2_allele):
    plt.sca(ax[i,J])
    mc = 'tab:blue' if ssk2_parent[i][0] == 'X' else 'tab:orange'
    plt.text(0.5,0.5,ssk2_parent[i],#+'$_{\it{%s}}$'%(k), 
             transform=ax[i,J].transAxes,
             va='center',ha='center',
             fontsize=14,color=mc)
    plt.axis('off')
    
nos = [20,7,10,6]
fs = [0,0,130,0]
for i,k in enumerate(nos):
    plt.sca(ax[i,-2])
    plt.text(0.5,0.5,k, transform=ax[i,-2].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    

for i,k in enumerate(fs):
    plt.sca(ax[i,-1])
    plt.text(0.5,0.5,k, transform=ax[i,-1].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
plt.sca(ax[0,2]);plt.title('# of\nResistant',fontsize=14)
plt.sca(ax[0,3]);plt.title('# of\nSensitive',fontsize=14);
plt.subplots_adjust(wspace=0.01)
#plt.savefig('../../FIGURES/Cdx_Finemap_Fludio_Results.png',
#           dpi=150,bbox_inches='tight');

# %%
fludio_path = '/Users/croth/Desktop/CRYPTO_QTL/FIGURES/fludio.png'
fludio = Image.open(fludio_path)
ypd_path = '/Users/croth/Desktop/CRYPTO_QTL/FIGURES/YPD_fludio.png'
ypd = Image.open(ypd_path)

# %%
fig,ax = plt.subplots(1,2,figsize=(6,3))

#axes= fig.add_axes([-1,0.1,.7,.7])
plt.sca(ax[0])
plt.title('YPD\n',fontsize=14)

plt.imshow(ypd)
plt.xticks([25,60,105,145],
           ['H99','$\it{ssk1\Delta}$',
            'XL280'+r'$\bf{a}$',
            '431'+'$\mathrm{\u03B1}$'],
           fontsize=14,rotation=90);
plt.yticks([24,60,100],['$10^6$','$10^5$','$10^4$'],fontsize=14)
plt.ylim(125,0)
plt.xlim(5,160)
plt.ylabel('Number of\nCells',fontsize=14)
#axes= fig.add_axes([-0,0.66,0.04,.21])


plt.sca(ax[1])
plt.title('Fludioxonil\n100 $\mu$g/ml',fontsize=14)
plt.imshow(fludio);
plt.yticks([],[])
plt.xticks([25,60,105,145],
           ['H99','$\it{ssk1\Delta}$',
            'XL280'+r'$\bf{a}$',
            '431'+'$\mathrm{\u03B1}$'],
           fontsize=14,rotation=90);
plt.ylim(125,0);
plt.xlim(4,160)
plt.subplots_adjust(wspace=0.25);
plt.savefig('/Users/croth/Desktop/CRYPTO_QTL/FIGURES/Cdx_parental_fludioxonil.png',
           dpi=150,bbox_inches='tight')

# %%
assert 1==2

# %%
fig,ax = plt.subplots(6,9,figsize=(10,4))
for i,j in enumerate(yimp):
    plt.sca(ax[i,2])
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    strain = j.split('/')[-1].split('_')[0]
    if strain == '431':
        strain = _431
    elif strain == 'xl280a':
        strain = xl280a
    else:
        pass
    plt.text(-0.95,0.5,strain, transform=ax[i,0].transAxes,
             va='center',ha='center',fontsize=14)
plt.sca(ax[0,2])
plt.title('YPD\n',fontsize=12)
plt.sca(ax[0,3])
plt.title('Fludioxonil\n100 $\mu$g/ml',fontsize=12)
for i,j in enumerate(fimp):
    plt.sca(ax[i,3])
    #im =  mpimg.imread(j)
    im = cv2.imread(j)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    #plt.imshow(im)#,cmap='gray')
    plt.axis('off')

plt.subplots_adjust(wspace=0.01)
for i,g in enumerate(genos):
    plt.sca(ax[i,0])
    sg = g[0]
    if sg == 0:
        s = xl280a
    else:
        assert sg == 1
        s = _431
    plt.text(0.5,0.5,s, transform=ax[i,0].transAxes,
             va='center',ha='center',fontsize=10)
    plt.axis('off')
    plt.sca(ax[i,1])
    sg = g[1]
    if sg == 0:
        s = xl280a
    else:
        assert sg == 1
        s = _431
    plt.text(0.5,0.5,s, transform=ax[i,1].transAxes,
             va='center',ha='center',fontsize=10)
    plt.axis('off')
plt.sca(ax[0,0]);plt.title('$SSK1$\nAllele',fontsize=12)
plt.sca(ax[0,1]);plt.title('$SSK2$\nAllele',fontsize=12)
axes= fig.add_axes([.505,0.1,0.01,.9])
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.spines['bottom'].set_visible(False)
axes.set_yticks([])
axes.set_xticks([])
plt.sca(ax[0,5]);plt.title('$SSK1$\nAllele',fontsize=12)
plt.sca(ax[0,6]);plt.title('$SSK2$\nAllele',fontsize=12)
ssk1_allele = [xl280a,_431,_431,xl280a]
ssk2_allele = [xl280a,_431,xl280a,_431]
for i,k in enumerate(ssk1_allele):
    plt.sca(ax[i,5])
    plt.text(0.5,0.5,k, transform=ax[i,5].transAxes,
             va='center',ha='center',fontsize=10)
    plt.axis('off')
for i,k in enumerate(ssk2_allele):
    plt.sca(ax[i,6])
    plt.text(0.5,0.5,k, transform=ax[i,6].transAxes,
             va='center',ha='center',fontsize=10)
    plt.axis('off')
#plt.sca(ax[0,7]);plt.title('Number of\nSegregants',fontsize=10)
plt.sca(ax[0,7]);plt.title('# of\nResistant',fontsize=12)
plt.sca(ax[0,8]);plt.title('# of\nSensitive',fontsize=12)
#plt.text(1.5,1.5,'Number of Se')
#plt.sca(ax[0,8]);plt.title('Fludioxonil\nSusceptible',fontsize=10)
plt.subplots_adjust(wspace=0.75);
for i in range(len(yimp)):
    plt.sca(ax[i,4]);plt.axis('off')
    
for i in np.arange(5,9,1):
    plt.sca(ax[-1,i]);plt.axis('off')
    plt.sca(ax[-2,i]);plt.axis('off')
    
nos = [29,19,37,5]
fs = [0,0,0,14]
for i,k in enumerate(nos):
    plt.sca(ax[i,-2])
    plt.text(0.5,0.5,k, transform=ax[i,-2].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
for i,k in enumerate(fs):
    plt.sca(ax[i,-1])
    plt.text(0.5,0.5,k, transform=ax[i,-1].transAxes,
             va='center',ha='center',fontsize=14)
    plt.axis('off')
    
plt.text(-0.5,3,'A', transform=ax[0,0].transAxes,
             va='center',ha='center',fontsize=14,fontweight='bold');
plt.text(-0.5,3,'B', transform=ax[0,5].transAxes,
             va='center',ha='center',fontsize=14,fontweight='bold');
plt.savefig('../../FIGURES/Cdx_Fludio_Results.png',
            dpi=150,bbox_inches='tight');
